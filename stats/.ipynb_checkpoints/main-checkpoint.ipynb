# %%
import polars as pl
import datashader as ds
import datashader.transfer_functions as tf
import matplotlib.pyplot as plt

file = 'english'

# Leggi il file con Polars, specificando il tipo di dati per la colonna
df = pl.read_csv(f'delays_txt/{file}_delays.txt', has_header=False, dtypes={"column_1": pl.Float64})
df = df.rename({'column_1': 'y'})

# Aggiungi la colonna 'x'
df = df.with_columns([
    pl.Series(name='x', values=range(len(df)))
])

# Normalizza i valori della colonna 'y'
y_min = df['y'].min()
y_max = df['y'].max()
df = df.with_columns([
    ((df['y'] - y_min) / (y_max - y_min)).alias('y')
])

# Conversione a DataFrame Pandas per l'uso con Datashader
df_pandas = df.to_pandas()

# Descrizione del DataFrame (opzionale)
print(df_pandas.describe())

canvas = ds.Canvas(plot_width=2000, plot_height=1000)
agg = canvas.line(df_pandas, 'x', 'y', ds.count())

img = tf.shade(agg)
img = tf.set_background(img, "white").to_pil()

plt.figure(figsize=(20, 10))
plt.imshow(img, aspect='auto', extent=(0, len(df_pandas) - 1, 0, 1), origin='upper')
plt.title(f'Normalized Delays for text int.{file}.txt')
plt.ylabel('Normalized Delay')
plt.yticks(fontsize=12)
plt.ylim(0, 1)

plt.savefig(f'delays_png/{file}_delays_normalized.png', bbox_inches='tight', pad_inches=0.1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 9
#       6 file = 'english'
#       8 # Leggi il file con Polars, specificando il tipo di dati per la colonna
# ----> 9 df = pl.read_csv(f'delays_txt/{file}_delays.txt', has_header=False, dtypes={"column_1": pl.Float64})
#      10 df = df.rename({'column_1': 'y'})
#      12 # Aggiungi la colonna 'x'
#
# File ~/.local/lib/python3.10/site-packages/polars/_utils/deprecation.py:135, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     130 @wraps(function)
#     131 def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#     132     _rename_keyword_argument(
#     133         old_name, new_name, kwargs, function.__name__, version
#     134     )
# --> 135     return function(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/polars/_utils/deprecation.py:135, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     130 @wraps(function)
#     131 def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#     132     _rename_keyword_argument(
#     133         old_name, new_name, kwargs, function.__name__, version
#     134     )
# --> 135     return function(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/polars/_utils/deprecation.py:135, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     130 @wraps(function)
#     131 def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#     132     _rename_keyword_argument(
#     133         old_name, new_name, kwargs, function.__name__, version
#     134     )
# --> 135     return function(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/polars/io/csv/functions.py:419, in read_csv(source, has_header, columns, new_columns, separator, comment_prefix, quote_char, skip_rows, dtypes, schema, null_values, missing_utf8_is_empty_string, ignore_errors, try_parse_dates, n_threads, infer_schema_length, batch_size, n_rows, encoding, low_memory, rechunk, use_pyarrow, storage_options, skip_rows_after_header, row_index_name, row_index_offset, sample_size, eol_char, raise_if_empty, truncate_ragged_lines, decimal_comma, glob)
#     407         dtypes = {
#     408             new_to_current.get(column_name, column_name): column_dtype
#     409             for column_name, column_dtype in dtypes.items()
#     410         }
#     412 with prepare_file_arg(
#     413     source,
#     414     encoding=encoding,
#    (...)
#     417     storage_options=storage_options,
#     418 ) as data:
# --> 419     df = _read_csv_impl(
#     420         data,
#     421         has_header=has_header,
#     422         columns=columns if columns else projection,
#     423         separator=separator,
#     424         comment_prefix=comment_prefix,
#     425         quote_char=quote_char,
#     426         skip_rows=skip_rows,
#     427         dtypes=dtypes,
#     428         schema=schema,
#     429         null_values=null_values,
#     430         missing_utf8_is_empty_string=missing_utf8_is_empty_string,
#     431         ignore_errors=ignore_errors,
#     432         try_parse_dates=try_parse_dates,
#     433         n_threads=n_threads,
#     434         infer_schema_length=infer_schema_length,
#     435         batch_size=batch_size,
#     436         n_rows=n_rows,
#     437         encoding=encoding if encoding == "utf8-lossy" else "utf8",
#     438         low_memory=low_memory,
#     439         rechunk=rechunk,
#     440         skip_rows_after_header=skip_rows_after_header,
#     441         row_index_name=row_index_name,
#     442         row_index_offset=row_index_offset,
#     443         sample_size=sample_size,
#     444         eol_char=eol_char,
#     445         raise_if_empty=raise_if_empty,
#     446         truncate_ragged_lines=truncate_ragged_lines,
#     447         decimal_comma=decimal_comma,
#     448         glob=glob,
#     449     )
#     451 if new_columns:
#     452     return _update_columns(df, new_columns)
#
# File ~/.local/lib/python3.10/site-packages/polars/io/csv/functions.py:565, in _read_csv_impl(source, has_header, columns, separator, comment_prefix, quote_char, skip_rows, dtypes, schema, null_values, missing_utf8_is_empty_string, ignore_errors, try_parse_dates, n_threads, infer_schema_length, batch_size, n_rows, encoding, low_memory, rechunk, skip_rows_after_header, row_index_name, row_index_offset, sample_size, eol_char, raise_if_empty, truncate_ragged_lines, decimal_comma, glob)
#     561         raise ValueError(msg)
#     563 projection, columns = parse_columns_arg(columns)
# --> 565 pydf = PyDataFrame.read_csv(
#     566     source,
#     567     infer_schema_length,
#     568     batch_size,
#     569     has_header,
#     570     ignore_errors,
#     571     n_rows,
#     572     skip_rows,
#     573     projection,
#     574     separator,
#     575     rechunk,
#     576     columns,
#     577     encoding,
#     578     n_threads,
#     579     path,
#     580     dtype_list,
#     581     dtype_slice,
#     582     low_memory,
#     583     comment_prefix,
#     584     quote_char,
#     585     processed_null_values,
#     586     missing_utf8_is_empty_string,
#     587     try_parse_dates,
#     588     skip_rows_after_header,
#     589     parse_row_index_args(row_index_name, row_index_offset),
#     590     sample_size=sample_size,
#     591     eol_char=eol_char,
#     592     raise_if_empty=raise_if_empty,
#     593     truncate_ragged_lines=truncate_ragged_lines,
#     594     decimal_comma=decimal_comma,
#     595     schema=schema,
#     596 )
#     597 return wrap_df(pydf)
#
# FileNotFoundError: No such file or directory (os error 2): delays_txt/english_delays.txt

# %%
import polars as pl
import datashader as ds
import datashader.transfer_functions as tf
import matplotlib.pyplot as plt

file = 'english'

# Leggi il file con Polars, specificando il tipo di dati per la colonna
df = pl.read_csv(f'delays_txt/{file}_delays.txt', has_header=False, dtypes={"column_1": pl.Float64})
df = df.rename({'column_1': 'y'})

# Aggiungi la colonna 'x'
df = df.with_columns([
    pl.Series(name='x', values=range(len(df)))
])

# Normalizza i valori della colonna 'y'
y_min = df['y'].min()
y_max = df['y'].max()
df = df.with_columns([
    ((df['y'] - y_min) / (y_max - y_min)).alias('y')
])

# Conversione a DataFrame Pandas per l'uso con Datashader
df_pandas = df.to_pandas()

# Descrizione del DataFrame (opzionale)
print(df_pandas.describe())

canvas = ds.Canvas(plot_width=2000, plot_height=1000)
agg = canvas.line(df_pandas, 'x', 'y', ds.count())

img = tf.shade(agg)
img = tf.set_background(img, "white").to_pil()

plt.figure(figsize=(20, 5))  # Modificato rapporto altezza/larghezza a 4:1
plt.imshow(img, aspect='auto', extent=(0, len(df_pandas) - 1, 0, 1), origin='upper')
plt.title(f'Normalized Delays for text int.{file}.txt')
plt.ylabel('Normalized Delay')
plt.yticks(fontsize=12)
plt.ylim(0, 1)

plt.savefig(f'delays_png/{file}_delays_normalized.png', bbox_inches='tight', pad_inches=0.1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 9
#       6 file = 'english'
#       8 # Leggi il file con Polars, specificando il tipo di dati per la colonna
# ----> 9 df = pl.read_csv(f'delays_txt/{file}_delays.txt', has_header=False, dtypes={"column_1": pl.Float64})
#      10 df = df.rename({'column_1': 'y'})
#      12 # Aggiungi la colonna 'x'
#
# File ~/.local/lib/python3.10/site-packages/polars/_utils/deprecation.py:135, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     130 @wraps(function)
#     131 def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#     132     _rename_keyword_argument(
#     133         old_name, new_name, kwargs, function.__name__, version
#     134     )
# --> 135     return function(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/polars/_utils/deprecation.py:135, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     130 @wraps(function)
#     131 def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#     132     _rename_keyword_argument(
#     133         old_name, new_name, kwargs, function.__name__, version
#     134     )
# --> 135     return function(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/polars/_utils/deprecation.py:135, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     130 @wraps(function)
#     131 def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#     132     _rename_keyword_argument(
#     133         old_name, new_name, kwargs, function.__name__, version
#     134     )
# --> 135     return function(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/polars/io/csv/functions.py:419, in read_csv(source, has_header, columns, new_columns, separator, comment_prefix, quote_char, skip_rows, dtypes, schema, null_values, missing_utf8_is_empty_string, ignore_errors, try_parse_dates, n_threads, infer_schema_length, batch_size, n_rows, encoding, low_memory, rechunk, use_pyarrow, storage_options, skip_rows_after_header, row_index_name, row_index_offset, sample_size, eol_char, raise_if_empty, truncate_ragged_lines, decimal_comma, glob)
#     407         dtypes = {
#     408             new_to_current.get(column_name, column_name): column_dtype
#     409             for column_name, column_dtype in dtypes.items()
#     410         }
#     412 with prepare_file_arg(
#     413     source,
#     414     encoding=encoding,
#    (...)
#     417     storage_options=storage_options,
#     418 ) as data:
# --> 419     df = _read_csv_impl(
#     420         data,
#     421         has_header=has_header,
#     422         columns=columns if columns else projection,
#     423         separator=separator,
#     424         comment_prefix=comment_prefix,
#     425         quote_char=quote_char,
#     426         skip_rows=skip_rows,
#     427         dtypes=dtypes,
#     428         schema=schema,
#     429         null_values=null_values,
#     430         missing_utf8_is_empty_string=missing_utf8_is_empty_string,
#     431         ignore_errors=ignore_errors,
#     432         try_parse_dates=try_parse_dates,
#     433         n_threads=n_threads,
#     434         infer_schema_length=infer_schema_length,
#     435         batch_size=batch_size,
#     436         n_rows=n_rows,
#     437         encoding=encoding if encoding == "utf8-lossy" else "utf8",
#     438         low_memory=low_memory,
#     439         rechunk=rechunk,
#     440         skip_rows_after_header=skip_rows_after_header,
#     441         row_index_name=row_index_name,
#     442         row_index_offset=row_index_offset,
#     443         sample_size=sample_size,
#     444         eol_char=eol_char,
#     445         raise_if_empty=raise_if_empty,
#     446         truncate_ragged_lines=truncate_ragged_lines,
#     447         decimal_comma=decimal_comma,
#     448         glob=glob,
#     449     )
#     451 if new_columns:
#     452     return _update_columns(df, new_columns)
#
# File ~/.local/lib/python3.10/site-packages/polars/io/csv/functions.py:565, in _read_csv_impl(source, has_header, columns, separator, comment_prefix, quote_char, skip_rows, dtypes, schema, null_values, missing_utf8_is_empty_string, ignore_errors, try_parse_dates, n_threads, infer_schema_length, batch_size, n_rows, encoding, low_memory, rechunk, skip_rows_after_header, row_index_name, row_index_offset, sample_size, eol_char, raise_if_empty, truncate_ragged_lines, decimal_comma, glob)
#     561         raise ValueError(msg)
#     563 projection, columns = parse_columns_arg(columns)
# --> 565 pydf = PyDataFrame.read_csv(
#     566     source,
#     567     infer_schema_length,
#     568     batch_size,
#     569     has_header,
#     570     ignore_errors,
#     571     n_rows,
#     572     skip_rows,
#     573     projection,
#     574     separator,
#     575     rechunk,
#     576     columns,
#     577     encoding,
#     578     n_threads,
#     579     path,
#     580     dtype_list,
#     581     dtype_slice,
#     582     low_memory,
#     583     comment_prefix,
#     584     quote_char,
#     585     processed_null_values,
#     586     missing_utf8_is_empty_string,
#     587     try_parse_dates,
#     588     skip_rows_after_header,
#     589     parse_row_index_args(row_index_name, row_index_offset),
#     590     sample_size=sample_size,
#     591     eol_char=eol_char,
#     592     raise_if_empty=raise_if_empty,
#     593     truncate_ragged_lines=truncate_ragged_lines,
#     594     decimal_comma=decimal_comma,
#     595     schema=schema,
#     596 )
#     597 return wrap_df(pydf)
#
# FileNotFoundError: No such file or directory (os error 2): delays_txt/english_delays.txt
